# %% [markdown]
# # Lab | Data Cleaning and Formatting

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv

# %% [markdown]
# # Challenge 1: Data Cleaning and Formatting

# %% [markdown]
# ## Exercise 1: Cleaning Column Names

# %% [markdown]
# To ensure consistency and ease of use, standardize the column names of the dataframe. Start by taking a first look at the dataframe and identifying any column names that need to be modified. Use appropriate naming conventions and make sure that column names are descriptive and informative.
#
# *Hint*:
# - *Column names should be in lower case*
# - *White spaces in column names should be replaced by `_`*
# - *`st` could be replaced for `state`*

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
data_bootcamp_vfour = pd.read_csv(url)

# %%
dbvf = data_bootcamp_vfour

# %%
dbvf
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
print("Original columns:", dbvf.columns.tolist())
# Out:
# Original columns: ['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']

# %%
# Function to clean column names
def clean_column_names(columns):
    new_cols = []
    for col in columns:
        col = col.upper()                 
        col = col.strip()                 
        col = col.replace(" ", "_")         
        new_cols.append(col)
    return new_cols

# %%
dbvf.columns = clean_column_names(dbvf.columns)

# %%
dbvf
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Rename specific columns
dbvf = dbvf.rename(columns={"ST": "STATE"})

# %%
dbvf
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# ## Exercise 2: Cleaning invalid Values

# %% [markdown]
# The dataset contains columns with inconsistent and incorrect values that could affect the accuracy of our analysis. Therefore, we need to clean these columns to ensure that they only contain valid data.
#
# Note that this exercise will focus only on cleaning inconsistent values and will not involve handling null values (NaN or None).
#
# *Hint*:
# - *Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".*
# - *State abbreviations be can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"*
# - *In education, "Bachelors" could be replaced by "Bachelor"*
# - *In Customer Lifetime Value, delete the `%` character*
# - *In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"*

# %%
#1-Standardize inconsistent values of gender

# %%
unique_genders = dbvf["GENDER"].unique()
print(unique_genders)
# Out:
# [nan 'F' 'M' 'Femal' 'Male' 'female']

# %%
dbvf["GENDER"] = dbvf["GENDER"].replace({
    "Femal": "F",
    "female": "F",
    "Male": "M" })

# %%
#check
unique_genders = dbvf["GENDER"].unique()
print(unique_genders)
# Out:
# [nan 'F' 'M']

# %%
#2-Replace state abbreviations with full names

# %%
unique_states = dbvf["STATE"].unique()
print(unique_states)
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' 'Cali' 'AZ' 'WA'
#  nan]

# %%
state_mapping = {
    "AZ": "Arizona",
    "Cali": "California",
    "WA": "Washington"
}
dbvf["STATE"] = dbvf["STATE"].replace(state_mapping)

# %%
#check
stand_states = dbvf["STATE"].unique()
print(stand_states)
# Out:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon' nan]

# %%
#3-In education, "Bachelors" could be replaced by "Bachelor"

# %%
education_uniques = dbvf["EDUCATION"].unique()
print(education_uniques)
# Out:
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Bachelors' 'Doctor'
#  nan]

# %%
dbvf["EDUCATION"] = dbvf["EDUCATION"].replace({"Bachelors": "Bachelor"})

# %%
#check
stand_education = dbvf["EDUCATION"].unique()
print(stand_education)
# Out:
# ['Master' 'Bachelor' 'High School or Below' 'College' 'Doctor' nan]

# %%
#4-In Customer Lifetime Value, delete the % character

# %%
dbvf["CUSTOMER_LIFETIME_VALUE"] = dbvf["CUSTOMER_LIFETIME_VALUE"].str.replace("%", "")

# %%
#check
print(dbvf["CUSTOMER_LIFETIME_VALUE"])
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: CUSTOMER_LIFETIME_VALUE, Length: 4008, dtype: object

# %%
#5-In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"

# %%
dbvf["VEHICLE_CLASS"] = dbvf["VEHICLE_CLASS"].replace({
    "Sports Car": "Luxury",
    "Luxury SUV": "Luxury",
    "Luxury Car": "Luxury"
})

# %%
#check
veh_cl_unique = dbvf["VEHICLE_CLASS"].unique()
print(veh_cl_unique)
# Out:
# ['Four-Door Car' 'Two-Door Car' 'SUV' 'Luxury' nan]

# %% [markdown]
# ## Exercise 3: Formatting data types

# %% [markdown]
# The data types of many columns in the dataset appear to be incorrect. This could impact the accuracy of our analysis. To ensure accurate analysis, we need to correct the data types of these columns. Please update the data types of the columns as appropriate.

# %% [markdown]
# It is important to note that this exercise does not involve handling null values (NaN or None).

# %% [markdown]
# *Hint*:
# - *Customer lifetime value should be numeric*
# - *Number of open complaints has an incorrect format. Look at the different values it takes with `unique()` and take the middle value. As an example, 1/5/00 should be 5. Number of open complaints is a string - remember you can use `split()` to deal with it and take the number you need. Finally, since it should be numeric, cast the column to be in its proper type.*

# %%
#Customer lifetime value should be numeric

# %%
dbvf["CUSTOMER_LIFETIME_VALUE"] = pd.to_numeric(dbvf["CUSTOMER_LIFETIME_VALUE"], errors='coerce')

# %%
#check
print(dbvf["CUSTOMER_LIFETIME_VALUE"].dtype)
# Out:
# float64

# %%
#Number of open complaints has an incorrect format. 
#Look at the different values it takes with unique() and take the middle value. 
#As an example, 1/5/00 should be 5. Number of open complaints is a string - remember you can use split() 
#to deal with it and take the number you need. 
#Finally, since it should be numeric, cast the column to be in its proper type.

# %%
print(dbvf["NUMBER_OF_OPEN_COMPLAINTS"].unique())
# Out:
# ['1/0/00' '1/2/00' '1/1/00' '1/3/00' '1/5/00' '1/4/00' nan]

# %%
#function to extract the middle value

def extract_middle(value):
    if pd.isna(value):
        return 0  
    parts = str(value).split("/")  
    if len(parts) >= 2:
        return parts[1]  # take the middle element
    return parts[0]  # fallback if format is not as expected

# %%
dbvf["NUMBER_OF_OPEN_COMPLAINTS"] = dbvf["NUMBER_OF_OPEN_COMPLAINTS"].apply(extract_middle)

# %%
dbvf["NUMBER_OF_OPEN_COMPLAINTS"] = pd.to_numeric(dbvf["NUMBER_OF_OPEN_COMPLAINTS"], errors='coerce')

# %%
#check
print(dbvf["NUMBER_OF_OPEN_COMPLAINTS"].head())
print(dbvf["NUMBER_OF_OPEN_COMPLAINTS"].dtype)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: NUMBER_OF_OPEN_COMPLAINTS, dtype: int64
# int64

# %% [markdown]
# ## Exercise 4: Dealing with Null values

# %% [markdown]
# Identify any columns with null or missing values. Identify how many null values each column has. You can use the `isnull()` function in pandas to find columns with null values.
#
# Decide on a strategy for handling the null values. There are several options, including:
#
# - Drop the rows or columns with null values
# - Fill the null values with a specific value (such as the column mean or median for numerical variables, and mode for categorical variables)
# - Fill the null values with the previous or next value in the column
# - Fill the null values based on a more complex algorithm or model (note: we haven't covered this yet)
#
# Implement your chosen strategy to handle the null values. You can use the `fillna()` function in pandas to fill null values or `dropna()` function to drop null values.
#
# Verify that your strategy has successfully handled the null values. You can use the `isnull()` function again to check if there are still null values in the dataset.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling null values.
#
# After formatting data types, as a last step, convert all the numeric variables to integers.

# %%
#Drop the rows or columns with null values

# %%
dbvf.dropna(inplace=True)
print(dbvf)
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# 3                   764586.18      0.0                 106.0
# ...

# %%
#Fill the null values with a specific value (such as the column mean or median for numerical variables, and mode for categorical variables)

# %%
print(dbvf.dtypes)
# Out:
# CUSTOMER                      object
# STATE                         object
# GENDER                        object
# EDUCATION                     object
# CUSTOMER_LIFETIME_VALUE      float64
# INCOME                       float64
# MONTHLY_PREMIUM_AUTO         float64
# NUMBER_OF_OPEN_COMPLAINTS      int64
# POLICY_TYPE                   object
# VEHICLE_CLASS                 object
# TOTAL_CLAIM_AMOUNT           float64
# dtype: object

# %%
numerical_cols = dbvf.select_dtypes(include=['int64', 'float64']).columns
print("Numerical columns:", numerical_cols)
# Out:
# Numerical columns: Index(['CUSTOMER_LIFETIME_VALUE', 'INCOME', 'MONTHLY_PREMIUM_AUTO',
#        'NUMBER_OF_OPEN_COMPLAINTS', 'TOTAL_CLAIM_AMOUNT'],
#       dtype='object')

# %%
categorical_cols = dbvf.select_dtypes(include=['object', 'category']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: Index(['CUSTOMER', 'STATE', 'GENDER', 'EDUCATION', 'POLICY_TYPE',
#        'VEHICLE_CLASS'],
#       dtype='object')

# %%
for col in numerical_cols:
    if col in dbvf.columns:
        dbvf[col].fillna(dbvf[col].mean(), inplace=True)

# %%
#check
print(dbvf[numerical_cols].isnull().sum())
# Out:
# CUSTOMER_LIFETIME_VALUE      0
# INCOME                       0
# MONTHLY_PREMIUM_AUTO         0
# NUMBER_OF_OPEN_COMPLAINTS    0
# TOTAL_CLAIM_AMOUNT           0
# dtype: int64

# %%
for col in categorical_cols:
    if col in dbvf.columns:
        dbvf[col].fillna(dbvf[col].mode()[0], inplace=True)

# %%
#check
print(dbvf[categorical_cols].isnull().sum())
# Out:
# CUSTOMER         0
# STATE            0
# GENDER           0
# EDUCATION        0
# POLICY_TYPE      0
# VEHICLE_CLASS    0
# dtype: int64

# %%
#Fill the null values with the previous or next value in the column

    ## Fill NaN with the previous value in each column
dbvf.fillna(method='ffill', inplace=True)

    ## Fill NaN with the next value in each column
dbvf.fillna(method='bfill', inplace=True)

# %% [markdown]
# ## Exercise 5: Dealing with duplicates

# %% [markdown]
# Use the `.duplicated()` method to identify any duplicate rows in the dataframe.
#
# Decide on a strategy for handling the duplicates. Options include:
# - Dropping all duplicate rows
# - Keeping only the first occurrence of each duplicated row
# - Keeping only the last occurrence of each duplicated row
# - Dropping duplicates based on a subset of columns
# - Dropping duplicates based on a specific column
#
# Implement your chosen strategy using the `drop_duplicates()` function.
#
# Verify that your strategy has successfully handled the duplicates by checking for duplicates again using `.duplicated()`.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling duplicates.
#
# Save the cleaned dataset to a new CSV file.
#
# *Hint*: *after dropping duplicates, reset the index to ensure consistency*.

# %%
#Dropping all duplicate rows

# %%
dbvf.drop_duplicates(inplace=True)

# %%
#Keeping only the first occurrence of each duplicated row

# %%
dbvf.drop_duplicates(keep='first', inplace=True)

# %%
#Keeping only the last occurrence of each duplicated row

# %%
dbvf.drop_duplicates(keep='last', inplace=True)

# %%
#Dropping duplicates based on a subset of columns

# %%
#Example: drop duplicates based on 'Customer ID' and 'Policy Type'
#dbvf.drop_duplicates(subset=['Customer ID', 'Policy Type'], inplace=True)

    #Keep the first occurrence (default)
    #dbvf.drop_duplicates(subset=['Customer ID', 'Policy Type'], keep='first', inplace=True)

    #Keep the last occurrence
    #dbvf.drop_duplicates(subset=['Customer ID', 'Policy Type'], keep='last', inplace=True)

    #Remove all duplicates entirely
    #dbvf.drop_duplicates(subset=['Customer ID', 'Policy Type'], keep=False, inplace=True)

# %%
#Dropping duplicates based on a specific column

# %%
#Drop duplicate rows based on 'Customer ID', keep the first occurrence
#dbvf.drop_duplicates(subset=['Customer ID'], keep='first', inplace=True)

#Drop duplicate rows based on 'Customer ID', keep the last occurrence
#dbvf.drop_duplicates(subset=['Customer ID'], keep='last', inplace=True)

#Remove all duplicates entirely
#dbvf.drop_duplicates(subset=['Customer ID'], keep=False, inplace=True)

# %%
#check
print(dbvf.duplicated().sum()) # should be 0
# Out:
# 0

# %% [markdown]
# # Bonus: Challenge 2: creating functions on a separate `py` file

# %% [markdown]
# Put all the data cleaning and formatting steps into functions, and create a main function that performs all the cleaning and formatting.
#
# Write these functions in separate .py file(s). By putting these steps into functions, we can make the code more modular and easier to maintain.

# %% [markdown]
# *Hint: autoreload module is a utility module in Python that allows you to automatically reload modules in the current session when changes are made to the source code. This can be useful in situations where you are actively developing code and want to see the effects of changes you make without having to constantly restart the Python interpreter or Jupyter Notebook kernel.*

# %%
# data_cleaning.py

import pandas as pd

def standardize_gender(dbvf, column="GENDER"):
    """Standardize Gender column to 'M' and 'F'."""
    if column in dbvf.columns:
        dbvf[column] = dbvf[column].str.upper().replace({
            "FEMALE": "F",
            "FEMAL": "F",
            "MALE": "M"
        })
    return dbvf
    
def standardize_states(dbvf, column="STATES"):
    """Replace state abbreviations with full names."""
    state_mapping = {
        "AZ": "Arizona",
        "Cali": "California",
        "WA": "Washington"
        }
    if column in df.columns:
        dbvf[column] = dbvf[column].replace(state_mapping)
    return dbvf

def standardize_education(dbvf, column="EDUCATION"):
    """Standardize education column (Bachelors -> Bachelor)."""
    if column in dbvf.columns:
        dbvf[column] = dbvf[column].replace({
            "Bachelors": "Bachelor"
        })
    return dbvf

def clean_customer_lifetime_value(dbvf, column="CUSTOMER_LIFETIME_VALUE"):
    """Remove % or $ and convert to numeric."""
    if column in df.columns:
        dbvf[column] = dbvf[column].astype(str).str.replace("%", "").str.replace("$", "").str.strip()
        dbvf[column] = pd.to_numeric(dbvf[column], errors='coerce')
    return dbvf

def standardize_vehicle_class(dbvf, column="VEHICLE_CLASS"):
    """Standardize vehicle class to simpler categories."""
    if column in df.columns:
        dbvf[column] = dbvf[column].replace({
            "Sports Car": "Luxury",
            "Luxury SUV": "Luxury",
            "Luxury Car": "Luxury"
        })
    return dbvf

def clean_number_of_open_complaints(dbvf, column="NUMBER_OF_OPEN_COMPLAINTS"):
    """Extract middle value from strings like '1/5/00' and convert to numeric."""
    if column in dbvf.columns:
        def extract_middle(value):
            if pd.isna(value):
                return 0
            parts = str(value).split("/")
            return int(parts[1]) if len(parts) >= 2 else int(parts[0])
        dbvf[column] = dbvf[column].apply(extract_middle)
    return dbvf

def fill_missing_values(dbvf):
    """Fill missing numeric values with mean, categorical with mode."""
    num_cols = dbvf.select_dtypes(include=['int64', 'float64']).columns
    cat_cols = dbvf.select_dtypes(include=['object', 'category']).columns

    for col in num_cols:
        dbvf[col].fillna(dbvf[col].mean(), inplace=True)
    for col in cat_cols:
        dbvf[col].fillna(dbvf[col].mode()[0], inplace=True)
    return dbvf

def drop_duplicates(dbvf, subset=None):
    """Drop duplicate rows based on optional subset of columns."""
    dbvf.drop_duplicates(subset=subset, keep='first', inplace=True)
    dbvf.reset_index(drop=True, inplace=True)
    return dbvf

def main(dbvf):
    """Main function to perform all cleaning and formatting steps."""
    dbvf = standardize_gender(dbvf)
    dbvf = standardize_states(dbvf)
    dbvf = standardize_education(dbvf)
    dbvf = clean_customer_lifetime_value(dbvf)
    dbvf = standardize_vehicle_class(dbvf)
    dbvf = clean_number_of_open_complaints(dbvf)
    dbvf = fill_missing_values(dbvf)
    dbvf = drop_duplicates(dbvf)
    return dbvf

# %%
print(dbvf)
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# 3                   764586.18      0.0                 106.0
# ...

# %% [markdown]
# # Bonus: Challenge 3: Analyzing Clean and Formated Data

# %% [markdown]
# You have been tasked with analyzing the data to identify potential areas for improving customer retention and profitability. Your goal is to identify customers with a high policy claim amount and a low customer lifetime value.
#
# In the Pandas Lab, we only looked at high policy claim amounts because we couldn't look into low customer lifetime values. If we had tried to work with that column, we wouldn't have been able to because customer lifetime value wasn't clean and in its proper format. So after cleaning and formatting the data, let's get some more interesting insights!
#
# Instructions:
#
# - Review the statistics again for total claim amount and customer lifetime value to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount and a low customer lifetime value. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount, and clients with a low customer lifetime value to be those in the bottom 25% of the customer lifetime value. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile and a customer lifetime value in the bottom 25th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount and low customer lifetime value data. To do so, select both columns of the dataframe simultaneously and pass it to the `.describe()` method. This will give you descriptive statistics, such as mean, median, standard deviation, minimum and maximum values for both columns at the same time, allowing you to compare and analyze their characteristics.

# %%
#Calculate thresholds for top/bottom 25%

# 75th percentile for Total Claim Amount
high_claim_threshold = dbvf["TOTAL_CLAIM_AMOUNT"].quantile(0.75)

# 25th percentile for Customer Lifetime Value
low_clv_threshold = dbvf["CUSTOMER_LIFETIME_VALUE"].quantile(0.25)

print(f"High claim threshold (75th percentile): {high_claim_threshold}")
print(f"Low CLV threshold (25th percentile): {low_clv_threshold}")
# Out:
# High claim threshold (75th percentile): 534.0
# Low CLV threshold (25th percentile): 411783.57999999996

# %%
#Filter customers meeting both conditions

high_claim_low_clv_df = dbvf.loc[
    (dbvf["TOTAL_CLAIM_AMOUNT"] > high_claim_threshold) &
    (dbvf["CUSTOMER_LIFETIME_VALUE"] < low_clv_threshold)
]

# Display the filtered dataframe
display(high_claim_low_clv_df)
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 140   DS81757      Oregon      M               College
# 158   KA61892     Arizona      M               College
# 160   ND87334  California      M  High School or Below
# 170   TS19868  California      M               College
# 179   HH90090  California      F              Bachelor
# 184   AB13432  California      M              Bachelor
# 204   FL34139  California      M  High School or Below
# 250   IA63417     Arizona      F  High School or Below
# 269   VZ51506     Arizona      F  High School or Below
# 279   OH60605      Oregon      F  High School or Below
# 304   RR77985      Oregon      F              Bachelor
# 388   JF36291  California      M               College
# 415   ZF84449      Oregon      F               College
# 448   NL93182      Nevada      M              Bachelor
# 450   WE68644      Oregon      F              Bachelor
# 467   AU96286      Oregon      F              Bachelor
# ...

# %%
#Calculate summary statistics for both columns

# Select both columns and use describe()
summary_stats = high_claim_low_clv_df[["TOTAL_CLAIM_AMOUNT", "CUSTOMER_LIFETIME_VALUE"]].describe()

print(summary_stats)
# Out:
#        TOTAL_CLAIM_AMOUNT  CUSTOMER_LIFETIME_VALUE
# count           35.000000                35.000000
# mean           712.065602            343009.593714
# std            145.436339             57540.924326
# min            537.600000            228759.690000
# 25%            631.919877            299913.535000
# 50%            679.368378            366737.500000
# 75%            757.535488            386921.190000
# max           1185.988301            407913.270000
